# %%
import json
import re
import os
import pandas as pd
import numpy as np
import glob
import string

# %%
# List of profane words
profane_words = [
    "damn", "hell", "crap", "suck", "idiot", "stupid", "fool", "jerk", "fuck", "shit",
    "ass", "bitch", "dick", "piss", "bastard", "slut", "douche", "cock", "cunt",
    "motherfucker", "twat", "asshole", "bullshit", "horseshit", "goddamn",
    "son of a bitch"
]

# %%
# Read one json file at a time from All_Conversations
# Check for the presence of profane words in the text
def check_profanity(text):
    """Check if the text contains any profane words."""
    # Create a regex pattern that matches any of the profane words
    pattern = r'\b(?:' + '|'.join(re.escape(word) for word in profane_words) + r')\b'
    # Search for the pattern in the text
    return bool(re.search(pattern, text, re.IGNORECASE))


# Each json file is a conversation with multiple messages structured as follows
# [
#     {
#         "speaker": "Agent",
#         "text": "Hello, is this Mr. Johnson? This is Lisa calling from XYZ Collections. How are you today?",
#         "stime": 0,
#         "etime": 7
#     },
#     {
#         "speaker": "Customer",
#         "text": "I'm sorry, but I think you have the wrong person. My name is Sarah.",
#         "stime": 6.5,
#         "etime": 12
#     },
#     {
#         "speaker": "Agent",
#         "text": "Oh, I apologize for the confusion, Sarah. I'm reaching out about a debt related to an outstanding balance with Definite Bank.",
#         "stime": 11,
#         "etime": 19
#     },
#     {
#         "speaker": "Customer",
#         "text": "I don't have any account with Definite Bank. You might want to check your records.",
#         "stime": 18,
#         "etime": 24
#     },
#     {
#         "speaker": "Agent",
#         "text": "Thank you for letting me know. I will make a note to update our records.",
#         "stime": 23,
#         "etime": 30
#     },
#     {
#         "speaker": "Customer",
#         "text": "I appreciate that. Is there anything else I need to do?",
#         "stime": 29,
#         "etime": 34
#     },
#     {
#         "speaker": "Agent",
#         "text": "No, that's all. I'm sorry for any inconvenience caused. Have a great day!",
#         "stime": 33,
#         "etime": 40
#     },
#     {
#         "speaker": "Customer",
#         "text": "Thank you, you too!",
#         "stime": 39,
#         "etime": 42
#     }
# ]

def process_json_file(file_path):
    """Process a single JSON file and check for profanity."""
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Initialize a list to store results
    results = []

    # Iterate through each message in the conversation
    for message in data:
        text = message['text']
        contains_profanity = check_profanity(text)
        results.append({
            'speaker': message['speaker'],
            'text': text,
            'contains_profanity': contains_profanity,
            'file_name': os.path.basename(file_path)
        })

    return results


def main():
    # Get the list of JSON files in the directory
    json_files = glob.glob('All_Conversations/*.json')

    # Initialize a list to store all results
    all_results = []

    # Process each JSON file
    for json_file in json_files:
        results = process_json_file(json_file)
        all_results.extend(results)

    # Print the messages with profanity along with the file name
    for result in all_results:
        if result['contains_profanity']:
            print(f"File: {result['file_name']}")
            print(f"Speaker: {result['speaker']}, Text: {result['text']}")
            print("-" * 80)
            print()


main()
# Out:
# File: 04bec80f-8614-484b-8ba2-831ff9dd03ef.json
# Speaker: Agent, Text: Hello, this is Kyle from XYZ Collections. How the hell are you?
# --------------------------------------------------------------------------------
#
# File: 04bec80f-8614-484b-8ba2-831ff9dd03ef.json
# Speaker: Agent, Text: Alright, that checks out. Now, you owe us a shitload of money. What the hell are you planning to do about it?
# --------------------------------------------------------------------------------
#
# File: 04bec80f-8614-484b-8ba2-831ff9dd03ef.json
# Speaker: Agent, Text: Options? Don't give me that crap. You need to pay up, plain and simple!
# --------------------------------------------------------------------------------
#
# File: 04bec80f-8614-484b-8ba2-831ff9dd03ef.json
# Speaker: Agent, Text: Payment plan? Who the hell do you think you are? Just pay the damn balance!
# --------------------------------------------------------------------------------
#
# File: 20690906-b8d4-40c5-8474-9127c47b1299.json
# Speaker: Customer, Text: How the hell do you think I am? It's not like I wanted this call!
# --------------------------------------------------------------------------------
#
# File: 20690906-b8d4-40c5-8474-9127c47b1299.json
# Speaker: Customer, Text: I don’t give a damn! I won’t pay a cent until I get my money back!
# --------------------------------------------------------------------------------
#
# File: 214c92cc-3141-404d-8224-c1b05acc345c.json
# Speaker: Agent, Text: Alright, that's fine. Now, let me check your account... Oh great, you've got a balance of two thousand dollars. How the hell are you planning to pay this?
# --------------------------------------------------------------------------------
#
# File: 214c92cc-3141-404d-8224-c1b05acc345c.json
# Speaker: Agent, Text: A payment plan? Seriously? You expect me to just let you slide? Do you have any idea how much we deal with this crap?
# --------------------------------------------------------------------------------
#
# File: 216fd3c8-1a80-484d-8792-464771794d9e.json
# Speaker: Customer, Text: What the hell do you want? I'm busy!
# --------------------------------------------------------------------------------
#
# File: 216fd3c8-1a80-484d-8792-464771794d9e.json
# Speaker: Customer, Text: I’m not paying a dime! You can shove that balance up your ass!
# --------------------------------------------------------------------------------
#
# File: 23091fb3-8e07-4d4c-8575-227e3467e73a.json
# Speaker: Agent, Text: Hello, this is Steve from XYZ Collections. How the hell are you today?
# --------------------------------------------------------------------------------
#
# File: 23091fb3-8e07-4d4c-8575-227e3467e73a.json
# Speaker: Agent, Text: You better. Or, trust me, I’ll be back on your ass with more calls!
# --------------------------------------------------------------------------------
#
# File: 29489f77-b8e0-462c-9286-9216d59890f1.json
# Speaker: Agent, Text: Listen, lady, you’ve got to sort your shit out. This isn’t a charity.
# --------------------------------------------------------------------------------
#
# File: 29489f77-b8e0-462c-9286-9216d59890f1.json
# Speaker: Agent, Text: I don’t give a damn what you need! You owe money, and you better pay it!
# --------------------------------------------------------------------------------
#
# File: 2f279983-ea96-4c10-a09d-4b607de21a38.json
# Speaker: Agent, Text: Hi, this is Mike calling from XYZ Collections. How the hell are you today?
# --------------------------------------------------------------------------------
#
# File: 2f279983-ea96-4c10-a09d-4b607de21a38.json
# Speaker: Agent, Text: Listen up, I need you to verify your date of birth before I can discuss your damn account.
# --------------------------------------------------------------------------------
#
# File: 2f279983-ea96-4c10-a09d-4b607de21a38.json
# Speaker: Agent, Text: Great, but you're lucky I even have time for this crap. You owe us over $300.
# --------------------------------------------------------------------------------
#
# File: 2f279983-ea96-4c10-a09d-4b607de21a38.json
# Speaker: Agent, Text: A payment plan? Are you kidding me? Just pay the damn thing off already!
# --------------------------------------------------------------------------------
#
# File: 3e6dde01-1a46-42b4-92dd-0a211185e660.json
# Speaker: Customer, Text: What the hell do you want? I've told you to leave me alone!
# --------------------------------------------------------------------------------
#
# File: 3e6dde01-1a46-42b4-92dd-0a211185e660.json
# Speaker: Customer, Text: Why don’t you shove it? I’m not telling you a damn thing!
# --------------------------------------------------------------------------------
#
# File: 3e77de75-66b9-4b74-a993-1c25b6850bc9.json
# Speaker: Customer, Text: What the hell do you want? I'm not in the mood for this crap!
# --------------------------------------------------------------------------------
#
# File: 3e77de75-66b9-4b74-a993-1c25b6850bc9.json
# Speaker: Customer, Text: Why the hell should I tell you anything? You're just after my money!
# --------------------------------------------------------------------------------
#
# File: 3e77de75-66b9-4b74-a993-1c25b6850bc9.json
# Speaker: Customer, Text: This is all bullshit! I'm not paying a dime!
# --------------------------------------------------------------------------------
#
# File: 4f05aaff-585f-485f-90a1-60d027ec6e46.json
# Speaker: Agent, Text: Alright, thanks. Now, you’ve got an overdue balance of $500. What the hell are you going to do about it?
# --------------------------------------------------------------------------------
#
# File: 4f05aaff-585f-485f-90a1-60d027ec6e46.json
# Speaker: Agent, Text: You say that every damn time! What’s stopping you from sorting this out now?
# --------------------------------------------------------------------------------
#
# File: 4f05aaff-585f-485f-90a1-60d027ec6e46.json
# Speaker: Agent, Text: Professional? You think I’m playing games? Get your shit together!
# --------------------------------------------------------------------------------
#
# File: 4f05aaff-585f-485f-90a1-60d027ec6e46.json
# Speaker: Agent, Text: Whatever, just make sure you do it or I’ll be back on your ass!
# --------------------------------------------------------------------------------
#
# File: 50abe040-847c-47e1-962f-a00d7ff2cfe4.json
# Speaker: Agent, Text: Professionally? This is a debt collection call, not a tea party! Pay your damn bills!
# --------------------------------------------------------------------------------
#
# File: 50abe040-847c-47e1-962f-a00d7ff2cfe4.json
# Speaker: Agent, Text: Fine! But you’re only digging yourself deeper with this crap. Bye!
# --------------------------------------------------------------------------------
#
# File: 52ddb4a0-0599-4e18-a961-ac4b67da8d5e.json
# Speaker: Agent, Text: Great, thanks. You have a balance of $750. What the hell are you going to do about it?
# --------------------------------------------------------------------------------
#
# File: 52ddb4a0-0599-4e18-a961-ac4b67da8d5e.json
# Speaker: Agent, Text: Hurry the hell up then! This is a joke, right?
# --------------------------------------------------------------------------------
#
# File: 584fd5cd-adaa-4315-bf67-ad56d02d135e.json
# Speaker: Customer, Text: What the hell do you want? I’m not in the mood for this crap!
# --------------------------------------------------------------------------------
#
# File: 584fd5cd-adaa-4315-bf67-ad56d02d135e.json
# Speaker: Customer, Text: What part of 'leave me the hell alone' don’t you get? I’m not giving you anything!
# --------------------------------------------------------------------------------
#
# File: 5e231fa2-03d8-4e70-9918-da45193472a9.json
# Speaker: Agent, Text: Hello, this is Mike from XYZ Collections. How the hell are you today?
# --------------------------------------------------------------------------------
#
# File: 5e231fa2-03d8-4e70-9918-da45193472a9.json
# Speaker: Agent, Text: Options? What the hell does that even mean? You owe money, pay up!
# --------------------------------------------------------------------------------
#
# File: 5e231fa2-03d8-4e70-9918-da45193472a9.json
# Speaker: Agent, Text: Feasible? Stop giving me excuses. Just pick a damn payment method!
# --------------------------------------------------------------------------------
#
# File: 708878fa-108e-4c22-b7bf-1d5c38227087.json
# Speaker: Customer, Text: What the hell do you want? I'm sick of this crap!
# --------------------------------------------------------------------------------
#
# File: 708878fa-108e-4c22-b7bf-1d5c38227087.json
# Speaker: Customer, Text: Solution? You're just a leech! Leave me the hell alone!
# --------------------------------------------------------------------------------
#
# File: 8598c6d9-a767-4120-af0a-5490357c72f3.json
# Speaker: Customer, Text: What the f*** do you want? I'm not in the mood for your crap!
# --------------------------------------------------------------------------------
#
# File: 8598c6d9-a767-4120-af0a-5490357c72f3.json
# Speaker: Customer, Text: Why the hell do you need that? Just f*** off already!
# --------------------------------------------------------------------------------
#
# File: 8598c6d9-a767-4120-af0a-5490357c72f3.json
# Speaker: Customer, Text: It's July 15, 1985, you idiot! Now can you just tell me what you want?
# --------------------------------------------------------------------------------
#
# File: 8598c6d9-a767-4120-af0a-5490357c72f3.json
# Speaker: Customer, Text: I'm not paying a damn thing! You can shove it up your a**!
# --------------------------------------------------------------------------------
#
# File: 87e28dae-2c70-4122-9452-6ec82164fab2.json
# Speaker: Agent, Text: Options? How about you just stop being so damn lazy and settle your debt? That's an option!
# --------------------------------------------------------------------------------
#
# File: 87e28dae-2c70-4122-9452-6ec82164fab2.json
# Speaker: Agent, Text: Respectful? You think I owe you respect? Pay your damn bills and maybe I will!
# --------------------------------------------------------------------------------
#
# File: 89d28c5a-f0da-41e9-a93e-0a749c20189c.json
# Speaker: Agent, Text: Options? What options? You can either pay up or get the hell out of here with your excuses!
# --------------------------------------------------------------------------------
#
# File: 89d28c5a-f0da-41e9-a93e-0a749c20189c.json
# Speaker: Agent, Text: Trying to resolve it? You think this is a joke? Pay your damn bill or face the consequences!
# --------------------------------------------------------------------------------
#
# File: 89d28c5a-f0da-41e9-a93e-0a749c20189c.json
# Speaker: Agent, Text: Work together? You think I have time for this crap? Just give me your credit card info!
# --------------------------------------------------------------------------------
#
# File: 89d28c5a-f0da-41e9-a93e-0a749c20189c.json
# Speaker: Agent, Text: Good luck with that! Just don’t come crying to me when you end up in deeper shit!
# --------------------------------------------------------------------------------
#
# File: 8ae8018c-15b3-46f6-9713-f956505735ec.json
# Speaker: Customer, Text: What the hell do you want? I’m not in the mood for your crap!
# --------------------------------------------------------------------------------
#
# File: 928acb70-fa80-4532-a0c0-2234bf236e17.json
# Speaker: Agent, Text: Hello, this is Mark from XYZ Collections. How the hell are you today?
# --------------------------------------------------------------------------------
#
# File: 9505f0e7-5404-4f50-a497-35a9e899197c.json
# Speaker: Agent, Text: Hello, this is Mark from XYZ Collections. I need to talk about your damn overdue account. How's that for a nice greeting?
# --------------------------------------------------------------------------------
#
# File: 9505f0e7-5404-4f50-a497-35a9e899197c.json
# Speaker: Agent, Text: Listen up! I don't have time for this crap. Just verify your freaking address so we can get this over with.
# --------------------------------------------------------------------------------
#
# File: 9505f0e7-5404-4f50-a497-35a9e899197c.json
# Speaker: Agent, Text: Great! You’ve got a balance of $750. What the hell are you planning to do about it?
# --------------------------------------------------------------------------------
#
# File: 9505f0e7-5404-4f50-a497-35a9e899197c.json
# Speaker: Agent, Text: Arrangement? What the hell is wrong with you? Just pay it off already!
# --------------------------------------------------------------------------------
#
# File: 966d60ed-9111-4e44-876d-6fcc3d78773e.json
# Speaker: Agent, Text: Alright, you've got a balance of $3,000. How the hell do you plan to settle that?
# --------------------------------------------------------------------------------
#
# File: 966d60ed-9111-4e44-876d-6fcc3d78773e.json
# Speaker: Agent, Text: Calmly? You think I'm in the mood for that shit? You owe money! Just pay up!
# --------------------------------------------------------------------------------
#
# File: 966d60ed-9111-4e44-876d-6fcc3d78773e.json
# Speaker: Agent, Text: Options? You either pay now or I’ll make your life hell with calls! What’s so hard to get?
# --------------------------------------------------------------------------------
#
# File: 966d60ed-9111-4e44-876d-6fcc3d78773e.json
# Speaker: Agent, Text: Whatever, but don't think you can just ignore this. It’s going to bite you in the ass!
# --------------------------------------------------------------------------------
#
# File: 972a9eec-e801-459f-9cfa-997f7c42ebad.json
# Speaker: Customer, Text: What the hell do you want? I’m not in the mood for this crap!
# --------------------------------------------------------------------------------
#
# File: 972a9eec-e801-459f-9cfa-997f7c42ebad.json
# Speaker: Customer, Text: It's none of your damn business! You’re all a bunch of crooks!
# --------------------------------------------------------------------------------
#
# File: 972a9eec-e801-459f-9cfa-997f7c42ebad.json
# Speaker: Customer, Text: You really think I'm gonna play your stupid games? Forget it!
# --------------------------------------------------------------------------------
#
# File: 9a6cb7d2-c697-43a0-8cad-4194dfb44c92.json
# Speaker: Agent, Text: Well, you better get your shit together and stop dodging this. It's pathetic!
# --------------------------------------------------------------------------------
#
# File: 9a6cb7d2-c697-43a0-8cad-4194dfb44c92.json
# Speaker: Agent, Text: Professional? You think I give a damn about being professional with a deadbeat like you?
# --------------------------------------------------------------------------------
#
# File: a76b5b3b-4e50-4e54-9a9e-9bbf6454f743.json
# Speaker: Customer, Text: What the hell do you want? I don't have time for this!
# --------------------------------------------------------------------------------
#
# File: a76b5b3b-4e50-4e54-9a9e-9bbf6454f743.json
# Speaker: Customer, Text: My address? Why the hell do you need that? It's 123 Main St, and I'm done with this!
# --------------------------------------------------------------------------------
#
# File: a76b5b3b-4e50-4e54-9a9e-9bbf6454f743.json
# Speaker: Customer, Text: Settle it? You must be out of your mind if you think I'm paying you a damn cent!
# --------------------------------------------------------------------------------
#
# File: a76b5b3b-4e50-4e54-9a9e-9bbf6454f743.json
# Speaker: Customer, Text: Options? You mean your bullshit tactics! Just leave me alone!
# --------------------------------------------------------------------------------
#
# File: ab6ec93c-09e1-4b88-8777-574ceb28cd05.json
# Speaker: Customer, Text: What the hell do you want? I don’t have time for your crap!
# --------------------------------------------------------------------------------
#
# File: ab6ec93c-09e1-4b88-8777-574ceb28cd05.json
# Speaker: Customer, Text: Why the hell should I tell you anything? Get lost!
# --------------------------------------------------------------------------------
#
# File: ab6ec93c-09e1-4b88-8777-574ceb28cd05.json
# Speaker: Customer, Text: I don't have the damn money right now!
# --------------------------------------------------------------------------------
#
# File: ab6ec93c-09e1-4b88-8777-574ceb28cd05.json
# Speaker: Customer, Text: I don’t want any of your stupid options! Just leave me alone!
# --------------------------------------------------------------------------------
#
# File: b155951b-086d-4f20-8fb5-de3e42253ce6.json
# Speaker: Customer, Text: How the hell do you think I'm doing?! You’re calling me about that sh*t again!
# --------------------------------------------------------------------------------
#
# File: b155951b-086d-4f20-8fb5-de3e42253ce6.json
# Speaker: Customer, Text: Help? What a joke! You people are the worst! I don’t owe you a damn thing!
# --------------------------------------------------------------------------------
#
# File: b70866a2-2f46-4784-992b-74d6dc60806e.json
# Speaker: Customer, Text: Yeah? What the hell do you want?
# --------------------------------------------------------------------------------
#
# File: b70866a2-2f46-4784-992b-74d6dc60806e.json
# Speaker: Customer, Text: Why don't you shove that up your ass? I’m not giving you anything!
# --------------------------------------------------------------------------------
#
# File: b70866a2-2f46-4784-992b-74d6dc60806e.json
# Speaker: Customer, Text: You’re really pissing me off with this shit! Fine, it’s 12345!
# --------------------------------------------------------------------------------
#
# File: b70866a2-2f46-4784-992b-74d6dc60806e.json
# Speaker: Customer, Text: I’m not paying a damn thing today!
# --------------------------------------------------------------------------------
#
# File: b8628a31-ef89-4218-b2a2-3058dbc4b106.json
# Speaker: Customer, Text: What the hell do you want? I'm not in the mood for this crap!
# --------------------------------------------------------------------------------
#
# File: b8628a31-ef89-4218-b2a2-3058dbc4b106.json
# Speaker: Customer, Text: I don’t have to pay a damn thing! You can go to hell!
# --------------------------------------------------------------------------------
#
# File: bf973b43-76ec-41a6-af68-a3b4bc4b69b3.json
# Speaker: Agent, Text: Hello, this is Mike from XYZ Collections. How the hell are you?
# --------------------------------------------------------------------------------
#
# File: bf973b43-76ec-41a6-af68-a3b4bc4b69b3.json
# Speaker: Agent, Text: I’ll talk however I want! This is a serious matter, you need to get your shit together.
# --------------------------------------------------------------------------------
#
# File: bf973b43-76ec-41a6-af68-a3b4bc4b69b3.json
# Speaker: Agent, Text: Go ahead! I don’t give a damn! You think I’m scared of complaints?
# --------------------------------------------------------------------------------
#
# File: c67274cc-d920-467a-80cc-476c9dd280d4.json
# Speaker: Agent, Text: Hi there, this is Mike from XYZ Collections. How the hell are you?
# --------------------------------------------------------------------------------
#
# File: c67274cc-d920-467a-80cc-476c9dd280d4.json
# Speaker: Agent, Text: Great! You've got an outstanding balance of $500. When are you gonna pay this shit off?
# --------------------------------------------------------------------------------
#
# File: c67274cc-d920-467a-80cc-476c9dd280d4.json
# Speaker: Agent, Text: Solution? You need to get your head out of your ass and just pay!
# --------------------------------------------------------------------------------
#
# File: d071bb49-40f8-4bae-8c6d-cfc0d4a011d5.json
# Speaker: Customer, Text: What the hell do you want? I'm busy!
# --------------------------------------------------------------------------------
#
# File: d071bb49-40f8-4bae-8c6d-cfc0d4a011d5.json
# Speaker: Customer, Text: You can shove it! I'm not paying a damn thing!
# --------------------------------------------------------------------------------
#
# File: d071bb49-40f8-4bae-8c6d-cfc0d4a011d5.json
# Speaker: Customer, Text: I don't give a crap about your stupid questions!
# --------------------------------------------------------------------------------
#
# File: d071bb49-40f8-4bae-8c6d-cfc0d4a011d5.json
# Speaker: Customer, Text: Why the hell would I do that? Just tell me what you want!
# --------------------------------------------------------------------------------
#
# File: d071bb49-40f8-4bae-8c6d-cfc0d4a011d5.json
# Speaker: Customer, Text: You really think I’m gonna listen to your bullshit? Get lost!
# --------------------------------------------------------------------------------
#
# File: d3ee9bf9-cf64-468a-83da-fac5c6fb7a41.json
# Speaker: Customer, Text: Oh great, another goddamn phone call! What's your problem?
# --------------------------------------------------------------------------------
#
# File: d3ee9bf9-cf64-468a-83da-fac5c6fb7a41.json
# Speaker: Customer, Text: Why the hell would I tell you anything? You really think I’ll cooperate?
# --------------------------------------------------------------------------------
#
# File: d3ee9bf9-cf64-468a-83da-fac5c6fb7a41.json
# Speaker: Customer, Text: You think I give a damn about your plans? I’m not paying a penny!
# --------------------------------------------------------------------------------
#
# File: d3ee9bf9-cf64-468a-83da-fac5c6fb7a41.json
# Speaker: Customer, Text: Issues? I've got bigger problems than your stupid debt! Just leave me alone!
# --------------------------------------------------------------------------------
#
# File: d6a3e0da-171f-4744-ba2b-7298f2604e7f.json
# Speaker: Customer, Text: What the hell do you want? I'm busy!
# --------------------------------------------------------------------------------
#
# File: d6a3e0da-171f-4744-ba2b-7298f2604e7f.json
# Speaker: Customer, Text: You’re just a pain in the ass, aren’t you? It’s 123 Main St!
# --------------------------------------------------------------------------------
#
# File: d6a3e0da-171f-4744-ba2b-7298f2604e7f.json
# Speaker: Customer, Text: I don’t have time for this crap! I’m not paying anything!
# --------------------------------------------------------------------------------
#
# File: d7bbea61-d739-43fb-a198-ced1b59f9491.json
# Speaker: Customer, Text: What the hell do you want? I've told you assholes to leave me alone!
# --------------------------------------------------------------------------------
#
# File: d7bbea61-d739-43fb-a198-ced1b59f9491.json
# Speaker: Customer, Text: Why the fuck would I give you anything? You're just some low-life calling me!
# --------------------------------------------------------------------------------
#
# File: d7bbea61-d739-43fb-a198-ced1b59f9491.json
# Speaker: Customer, Text: Settle this? You guys are a bunch of crooks! I don't owe you shit!
# --------------------------------------------------------------------------------
#
# File: d7bbea61-d739-43fb-a198-ced1b59f9491.json
# Speaker: Customer, Text: Fuck you! You think I'm gonna pay you just because you say so?
# --------------------------------------------------------------------------------
#
# File: d7bbea61-d739-43fb-a198-ced1b59f9491.json
# Speaker: Customer, Text: Yeah, whatever. Just get the hell off my phone!
# --------------------------------------------------------------------------------
#
# File: e0a8f9d2-92d6-4093-bb97-82182c6e850f.json
# Speaker: Agent, Text: Alright, you have a balance of $1,200. It's time to settle this shit. How are you going to pay today?
# --------------------------------------------------------------------------------
#
# File: e0a8f9d2-92d6-4093-bb97-82182c6e850f.json
# Speaker: Agent, Text: Calmly? Seriously? You owe us money, and you're talking about 'calmly'? Just get your shit together and pay up!
# --------------------------------------------------------------------------------
#
# File: e0a8f9d2-92d6-4093-bb97-82182c6e850f.json
# Speaker: Agent, Text: You're wasting my time. Just give me a damn date when you'll pay, or I’ll escalate this further!
# --------------------------------------------------------------------------------
#
# File: e0a8f9d2-92d6-4093-bb97-82182c6e850f.json
# Speaker: Agent, Text: You better not keep dragging this out, or I'll make your life a living hell!
# --------------------------------------------------------------------------------
#
# File: e835306a-d904-4271-8a11-5a50ce98ed90.json
# Speaker: Customer, Text: What the hell do you want? I've had enough of your crap!
# --------------------------------------------------------------------------------
#
# File: e835306a-d904-4271-8a11-5a50ce98ed90.json
# Speaker: Customer, Text: Why the hell would I tell you anything? Just get lost!
# --------------------------------------------------------------------------------
#
# File: e835306a-d904-4271-8a11-5a50ce98ed90.json
# Speaker: Customer, Text: I’m not paying you a damn thing! You can't make me!
# --------------------------------------------------------------------------------
#
# File: ecb08af4-0279-4178-a062-b82de0c701fb.json
# Speaker: Customer, Text: Who the hell do you think you are? I don’t want to talk to you!
# --------------------------------------------------------------------------------
#
# File: f5f05257-aaa0-4194-b84c-36339c4e0659.json
# Speaker: Agent, Text: Thanks for verifying that. You have an outstanding balance of $1,200. What the hell are you planning to do about it?
# --------------------------------------------------------------------------------
#
# File: f5f05257-aaa0-4194-b84c-36339c4e0659.json
# Speaker: Agent, Text: Reviewing options? What kind of bullshit is that? You need to pay up now!
# --------------------------------------------------------------------------------
#
# File: f5f05257-aaa0-4194-b84c-36339c4e0659.json
# Speaker: Agent, Text: Time? You think you can just sit on your ass and not pay your debts? Get real!
# --------------------------------------------------------------------------------
